# %%
def LCM(nums):
    len_nums = len(nums)
    bar = {}
    for i in range(0,len_nums):
        foo = nums[i]
        bar[foo] = []
        foo_ = foo
        while foo_ != 1:
            if foo_ % 2 == 0:
                bar[foo].append(2)
                foo_ = foo_/2
            elif foo_ % 3 == 0:
                bar[foo].append(3)
                foo_ = foo_/3
            elif foo_ % 5 == 0:
                bar[foo].append(5)
                foo_ = foo_/5
            elif foo_ % 7 == 0:
                bar[foo].append(7)
                foo_ = foo_/7
            elif foo_ % 11 == 0:
                bar[foo].append(11)
                foo_ = foo_/11
            elif foo_ % 13 == 0:
                bar[foo].append(13)
                foo_ = foo_/13
            elif foo_ % 17 == 0:
                bar[foo].append(17)
                foo_ = foo_/17
            elif foo_ % 23 == 0:
                bar[foo].append(23)
                foo_ = foo_/23
            elif foo_ % 29 == 0:
                bar[foo].append(29)
                foo_ = foo_/29
            elif foo_ % 31 == 0:
                bar[foo].append(31)
                foo_ = foo_/31
            elif foo_ % 37 == 0:
                bar[foo].append(37)
                foo_ = foo_/31
            elif foo_ % 41 == 0:
                bar[foo].append(41)
                foo_ = foo_/41
            elif foo_ % 47 == 0:
                bar[foo].append(47)
                foo_ = foo_/47
    x = 0
    j = 0
    for i in bar.keys():
        y = len(bar[i])
        if y > x:
            x = y
            j = i
        else:
            pass
    primes = []
    for i in bar[j]:
        for k in bar.keys():
            if i in bar[k]:
                primes.append(i)
                bar[k].remove(i)
            else:
                pass
    primes_1 = []
    for k in bar.keys():
        if bar[k] != []:
            for i in bar[k]:
                for k in bar.keys():
                    if i in bar[k]:
                        primes_1.append(i)
                        bar[k].remove(i)
                    else:
                        pass 
    primes_2 = []
    for k in bar.keys():
        if bar[k] != []:
            for i in bar[k]:
                for k in bar.keys():
                    if i in bar[k]:
                        primes_1.append(i)
                        bar[k].remove(i)
                    else:
                        primes_2.append(i)
    primes = set(primes)
    primes_1 = set(primes_1)
    primes_2 = set(primes_2)
    
    final_list = []
    for i in primes:
        final_list.append(i)
    for i in primes_1:
        final_list.append(i)
    for i in primes_2:
        final_list.append(i)
    mult = 1
    for i in final_list:
        mult*=i
    print(mult)

# %%
LCM([2,5,14,17,24,8,23,47])
# Out:
# 23155020

# %%
def HCF(nums):
    len_nums = len(nums)
    bar = {}
    for i in range(0,len_nums):
        foo = nums[i]
        bar[foo] = []
        foo_ = foo
        while foo_ != 1:
            if foo_ % 2 == 0:
                bar[foo].append(2)
                foo_ = foo_/2
            elif foo_ % 3 == 0:
                bar[foo].append(3)
                foo_ = foo_/3
            elif foo_ % 5 == 0:
                bar[foo].append(5)
                foo_ = foo_/5
            elif foo_ % 7 == 0:
                bar[foo].append(7)
                foo_ = foo_/7
            elif foo_ % 11 == 0:
                bar[foo].append(11)
                foo_ = foo_/11
            elif foo_ % 13 == 0:
                bar[foo].append(13)
                foo_ = foo_/13
            elif foo_ % 17 == 0:
                bar[foo].append(17)
                foo_ = foo_/17
            elif foo_ % 23 == 0:
                bar[foo].append(23)
                foo_ = foo_/23
            elif foo_ % 29 == 0:
                bar[foo].append(29)
                foo_ = foo_/29
            elif foo_ % 31 == 0:
                bar[foo].append(31)
                foo_ = foo_/31
            elif foo_ % 37 == 0:
                bar[foo].append(37)
                foo_ = foo_/31
            elif foo_ % 41 == 0:
                bar[foo].append(41)
                foo_ = foo_/41
            elif foo_ % 47 == 0:
                bar[foo].append(47)
                foo_ = foo_/47
    x = 0
    j = 0
    for i in bar.keys():
        y = len(bar[i])
        if y > x:
            x = y
            j = i
        else:
            pass
    common = []
    temp = bar[j]
    for i in temp:
        bool_ = 0
        for k in bar.keys():
            if i in bar[k]:
                bool_+=1
                bar[k].remove(i)
            else: 
                bool_ = bool_
        if bool_ == len(bar.keys()):
            common.append(i)
    for i in bar[j]:
        bool_ = 0
        for k in bar.keys():
            if i in bar[k]:
                bool_+=1
                bar[k].remove(i)
            else:
                bool_ = bool_
        if bool_ == len(bar.keys()):
            common.append(i)
    u = 1
    for i in common:
        u *= i
    print(u)

# %%
HCF([6,18,90])
# Out:
# 6

# %%
HCF([18,90])
# Out:
# 18
